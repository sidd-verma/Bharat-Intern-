# %% [markdown]
# <a href="https://colab.research.google.com/github/sidd-verma/Bharat-Intern-/blob/main/Stock_Prediction_By_Siddharth_Verma.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

df = pd.read_csv('MSFT.csv')

df
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 0     1986-03-13    0.088542    0.101563    0.088542    0.097222    0.060524
# 1     1986-03-14    0.097222    0.102431    0.097222    0.100694    0.062686
# 2     1986-03-17    0.100694    0.103299    0.100694    0.102431    0.063767
# 3     1986-03-18    0.102431    0.103299    0.098958    0.099826    0.062145
# 4     1986-03-19    0.099826    0.100694    0.097222    0.098090    0.061065
# ...          ...         ...         ...         ...         ...         ...
# 9397  2023-06-27  331.859985  336.149994  329.299988  334.570007  334.570007
# 9398  2023-06-28  334.660004  337.980011  333.809998  335.850006  335.850006
# 9399  2023-06-29  334.709991  336.109985  332.619995  335.049988  335.049988
# 9400  2023-06-30  337.750000  342.730011  337.200012  340.540009  340.540009
# 9401  2023-07-03  339.190002  340.899994  336.570007  337.989990  337.989990
#
#           Volume
# 0     1031788800
# 1      308160000
# 2      133171200
# 3       67766400
# 4       47894400
# ...          ...
# 9397    24354100
# 9398    20259500
# 9399    16997000
# 9400    26823800
# 9401    12508700
#
# [9402 rows x 7 columns]

# %%
df = df[['Date', 'Close']]

df
# Out:
#             Date       Close
# 0     1986-03-13    0.097222
# 1     1986-03-14    0.100694
# 2     1986-03-17    0.102431
# 3     1986-03-18    0.099826
# 4     1986-03-19    0.098090
# ...          ...         ...
# 9397  2023-06-27  334.570007
# 9398  2023-06-28  335.850006
# 9399  2023-06-29  335.049988
# 9400  2023-06-30  340.540009
# 9401  2023-07-03  337.989990
#
# [9402 rows x 2 columns]

# %%
df['Date']
# Out:
# 0       1986-03-13
# 1       1986-03-14
# 2       1986-03-17
# 3       1986-03-18
# 4       1986-03-19
#            ...
# 9397    2023-06-27
# 9398    2023-06-28
# 9399    2023-06-29
# 9400    2023-06-30
# 9401    2023-07-03
# Name: Date, Length: 9402, dtype: object

# %%
import datetime

def str_to_datetime(s):
  split = s.split('-')
  year, month, day = int(split[0]), int(split[1]), int(split[2])
  return datetime.datetime(year=year, month=month, day=day)

datetime_object = str_to_datetime('1986-03-19')
datetime_object
# Out:
# datetime.datetime(1986, 3, 19, 0, 0)

# %%
df
# Out:
#             Date       Close
# 0     1986-03-13    0.097222
# 1     1986-03-14    0.100694
# 2     1986-03-17    0.102431
# 3     1986-03-18    0.099826
# 4     1986-03-19    0.098090
# ...          ...         ...
# 9397  2023-06-27  334.570007
# 9398  2023-06-28  335.850006
# 9399  2023-06-29  335.049988
# 9400  2023-06-30  340.540009
# 9401  2023-07-03  337.989990
#
# [9402 rows x 2 columns]

# %%
df['Date'] = df['Date'].apply(str_to_datetime)
df['Date']
# Out:
# <ipython-input-6-f6fc52bb0fa5>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Date'] = df['Date'].apply(str_to_datetime)
# 0      1986-03-13
# 1      1986-03-14
# 2      1986-03-17
# 3      1986-03-18
# 4      1986-03-19
#           ...
# 9397   2023-06-27
# 9398   2023-06-28
# 9399   2023-06-29
# 9400   2023-06-30
# 9401   2023-07-03
# Name: Date, Length: 9402, dtype: datetime64[ns]

# %%
df.index = df.pop('Date')
df
# Out:
#                  Close
# Date
# 1986-03-13    0.097222
# 1986-03-14    0.100694
# 1986-03-17    0.102431
# 1986-03-18    0.099826
# 1986-03-19    0.098090
# ...                ...
# 2023-06-27  334.570007
# 2023-06-28  335.850006
# 2023-06-29  335.049988
# 2023-06-30  340.540009
# 2023-07-03  337.989990
#
# [9402 rows x 1 columns]

# %%
import matplotlib.pyplot as plt

plt.plot(df.index, df['Close'])

# %%
import numpy as np

def df_to_windowed_df(dataframe, first_date_str, last_date_str, n=3):
  first_date = str_to_datetime(first_date_str)
  last_date  = str_to_datetime(last_date_str)

  target_date = first_date

  dates = []
  X, Y = [], []

  last_time = False
  while True:
    df_subset = dataframe.loc[:target_date].tail(n+1)

    if len(df_subset) != n+1:
      print(f'Error: Window of size {n} is too large for date {target_date}')
      return

    values = df_subset['Close'].to_numpy()
    x, y = values[:-1], values[-1]

    dates.append(target_date)
    X.append(x)
    Y.append(y)

    next_week = dataframe.loc[target_date:target_date+datetime.timedelta(days=7)]
    next_datetime_str = str(next_week.head(2).tail(1).index.values[0])
    next_date_str = next_datetime_str.split('T')[0]
    year_month_day = next_date_str.split('-')
    year, month, day = year_month_day
    next_date = datetime.datetime(day=int(day), month=int(month), year=int(year))

    if last_time:
      break

    target_date = next_date

    if target_date == last_date:
      last_time = True

  ret_df = pd.DataFrame({})
  ret_df['Target Date'] = dates

  X = np.array(X)
  for i in range(0, n):
    X[:, i]
    ret_df[f'Target-{n-i}'] = X[:, i]

  ret_df['Target'] = Y

  return ret_df

# Start day second time around: '2021-03-25'
windowed_df = df_to_windowed_df(df,
                                '2021-03-25',
                                '2022-03-23',
                                n=3)
windowed_df
# Out:
#     Target Date    Target-3    Target-2    Target-1      Target
# 0    2021-03-25  235.990005  237.580002  235.460007  232.339996
# 1    2021-03-26  237.580002  235.460007  232.339996  236.479996
# 2    2021-03-29  235.460007  232.339996  236.479996  235.240005
# 3    2021-03-30  232.339996  236.479996  235.240005  231.850006
# 4    2021-03-31  236.479996  235.240005  231.850006  235.770004
# ..          ...         ...         ...         ...         ...
# 247  2022-03-17  276.440002  287.149994  294.390015  295.220001
# 248  2022-03-18  287.149994  294.390015  295.220001  300.429993
# 249  2022-03-21  294.390015  295.220001  300.429993  299.160004
# 250  2022-03-22  295.220001  300.429993  299.160004  304.059998
# 251  2022-03-23  300.429993  299.160004  304.059998  299.489990
#
# [252 rows x 5 columns]

# %%
def windowed_df_to_date_X_y(windowed_dataframe):
  df_as_np = windowed_dataframe.to_numpy()

  dates = df_as_np[:, 0]

  middle_matrix = df_as_np[:, 1:-1]
  X = middle_matrix.reshape((len(dates), middle_matrix.shape[1], 1))

  Y = df_as_np[:, -1]

  return dates, X.astype(np.float32), Y.astype(np.float32)

dates, X, y = windowed_df_to_date_X_y(windowed_df)

dates.shape, X.shape, y.shape
# Out:
# ((252,), (252, 3, 1), (252,))

# %%
q_80 = int(len(dates) * .8)
q_90 = int(len(dates) * .9)

dates_train, X_train, y_train = dates[:q_80], X[:q_80], y[:q_80]

dates_val, X_val, y_val = dates[q_80:q_90], X[q_80:q_90], y[q_80:q_90]
dates_test, X_test, y_test = dates[q_90:], X[q_90:], y[q_90:]

plt.plot(dates_train, y_train)
plt.plot(dates_val, y_val)
plt.plot(dates_test, y_test)

plt.legend(['Train', 'Validation', 'Test'])

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import layers

model = Sequential([layers.Input((3, 1)),
                    layers.LSTM(64),
                    layers.Dense(32, activation='relu'),
                    layers.Dense(32, activation='relu'),
                    layers.Dense(1)])

model.compile(loss='mse',
              optimizer=Adam(learning_rate=0.001),
              metrics=['mean_absolute_error'])

model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=100)
# Out:
# Epoch 1/100
# 7/7 [==============================] - 2s 65ms/step - loss: 85028.5859 - mean_absolute_error: 289.8597 - val_loss: 92759.2031 - val_mean_absolute_error: 304.4770
# Epoch 2/100
# 7/7 [==============================] - 0s 5ms/step - loss: 84814.0234 - mean_absolute_error: 289.4877 - val_loss: 92512.9375 - val_mean_absolute_error: 304.0723
# Epoch 3/100
# 7/7 [==============================] - 0s 5ms/step - loss: 84568.3281 - mean_absolute_error: 289.0646 - val_loss: 92267.0391 - val_mean_absolute_error: 303.6677
# Epoch 4/100
# 7/7 [==============================] - 0s 5ms/step - loss: 84350.0625 - mean_absolute_error: 288.6876 - val_loss: 92041.3906 - val_mean_absolute_error: 303.2959
# Epoch 5/100
# 7/7 [==============================] - 0s 5ms/step - loss: 84125.7500 - mean_absolute_error: 288.2971 - val_loss: 91773.2891 - val_mean_absolute_error: 302.8536
# Epoch 6/100
# 7/7 [==============================] - 0s 6ms/step - loss: 83848.7031 - mean_absolute_error: 287.8172 - val_loss: 91447.8203 - val_mean_absolute_error: 302.3158
# Epoch 7/100
# 7/7 [==============================] - 0s 5ms/step - loss: 83519.8516 - mean_absolute_error: 287.2464 - val_loss: 91057.6094 - val_mean_absolute_error: 301.6697
# Epoch 8/100
# 7/7 [==============================] - 0s 6ms/step - loss: 83079.9375 - mean_absolute_error: 286.4758 - val_loss: 90444.2578 - val_mean_absolute_error: 300.6515
# Epoch 9/100
# 7/7 [==============================] - 0s 6ms/step - loss: 82417.6797 - mean_absolute_error: 285.3188 - val_loss: 89620.5703 - val_mean_absolute_error: 299.2784
# Epoch 10/100
# 7/7 [==============================] - 0s 7ms/step - loss: 81533.2344 - mean_absolute_error: 283.7625 - val_loss: 88552.3906 - val_mean_absolute_error: 297.4885
# Epoch 11/100
# 7/7 [==============================] - 0s 6ms/step - loss: 80478.8984 - mean_absolute_error: 281.8999 - val_loss: 87304.1094 - val_mean_absolute_error: 295.3830
# Epoch 12/100
# 7/7 [==============================] - 0s 7ms/step - loss: 79201.9062 - mean_absolute_error: 279.6221 - val_loss: 85894.4297 - val_mean_absolute_error: 292.9872
# Epoch 13/100
# 7/7 [==============================] - 0s 6ms/step - loss: 77836.3594 - mean_absolute_error: 277.1683 - val_loss: 84339.4297 - val_mean_absolute_error: 290.3213
# Epoch 14/100
# 7/7 [==============================] - 0s 6ms/step - loss: 76254.7812 - mean_absolute_error: 274.3015 - val_loss: 82474.8203 - val_mean_absolute_error: 287.0920
# Epoch 15/100
# 7/7 [==============================] - 0s 6ms/step - loss: 74313.6094 - mean_absolute_error: 270.7370 - val_loss: 80083.2344 - val_mean_absolute_error: 282.8960
# Epoch 16/100
# 7/7 [==============================] - 0s 6ms/step - loss: 71873.2969 - mean_absolute_error: 266.1817 - val_loss: 77327.7734 - val_mean_absolute_error: 277.9834
# Epoch 17/100
# 7/7 [==============================] - 0s 7ms/step - loss: 69120.8828 - mean_absolute_error: 260.9954 - val_loss: 74061.4375 - val_mean_absolute_error: 272.0448
# Epoch 18/100
# 7/7 [==============================] - 0s 6ms/step - loss: 65862.4453 - mean_absolute_error: 254.6554 - val_loss: 70513.1484 - val_mean_absolute_error: 265.4433
# Epoch 19/100
# 7/7 [==============================] - 0s 7ms/step - loss: 62372.8320 - mean_absolute_error: 247.7183 - val_loss: 66456.2188 - val_mean_absolute_error: 257.6882
# Epoch 20/100
# 7/7 [==============================] - 0s 6ms/step - loss: 58494.5664 - mean_absolute_error: 239.7545 - val_loss: 62175.7695 - val_mean_absolute_error: 249.2444
# Epoch 21/100
# 7/7 [==============================] - 0s 6ms/step - loss: 54318.8867 - mean_absolute_error: 230.8736 - val_loss: 57410.5156 - val_mean_absolute_error: 239.4944
# Epoch 22/100
# 7/7 [==============================] - 0s 7ms/step - loss: 49732.9688 - mean_absolute_error: 220.7077 - val_loss: 52482.1094 - val_mean_absolute_error: 228.9741
# Epoch 23/100
# 7/7 [==============================] - 0s 7ms/step - loss: 45017.7812 - mean_absolute_error: 209.7864 - val_loss: 47117.3086 - val_mean_absolute_error: 216.9429
# Epoch 24/100
# 7/7 [==============================] - 0s 6ms/step - loss: 39859.4570 - mean_absolute_error: 197.1045 - val_loss: 41628.2812 - val_mean_absolute_error: 203.9003
# Epoch 25/100
# 7/7 [==============================] - 0s 5ms/step - loss: 34860.9688 - mean_absolute_error: 183.9483 - val_loss: 36239.8516 - val_mean_absolute_error: 190.2285
# Epoch 26/100
# 7/7 [==============================] - 0s 5ms/step - loss: 29808.0273 - mean_absolute_error: 169.7132 - val_loss: 30488.8516 - val_mean_absolute_error: 174.4585
# Epoch 27/100
# 7/7 [==============================] - 0s 6ms/step - loss: 24594.8164 - mean_absolute_error: 153.4917 - val_loss: 25159.9004 - val_mean_absolute_error: 158.4517
# Epoch 28/100
# 7/7 [==============================] - 0s 5ms/step - loss: 19915.0234 - mean_absolute_error: 137.4323 - val_loss: 20209.6504 - val_mean_absolute_error: 141.9738
# Epoch 29/100
# 7/7 [==============================] - 0s 7ms/step - loss: 15439.4092 - mean_absolute_error: 120.0989 - val_loss: 15276.0527 - val_mean_absolute_error: 123.3808
# Epoch 30/100
# 7/7 [==============================] - 0s 7ms/step - loss: 11258.7988 - mean_absolute_error: 101.2855 - val_loss: 11064.2334 - val_mean_absolute_error: 104.9340
# Epoch 31/100
# 7/7 [==============================] - 0s 8ms/step - loss: 7950.2544 - mean_absolute_error: 83.3973 - val_loss: 7729.0098 - val_mean_absolute_error: 87.6130
# Epoch 32/100
# 7/7 [==============================] - 0s 8ms/step - loss: 5452.9316 - mean_absolute_error: 66.3068 - val_loss: 5077.6538 - val_mean_absolute_error: 70.8850
# Epoch 33/100
# 7/7 [==============================] - 0s 7ms/step - loss: 3562.2253 - mean_absolute_error: 50.4730 - val_loss: 3166.8350 - val_mean_absolute_error: 55.8020
# Epoch 34/100
# 7/7 [==============================] - 0s 9ms/step - loss: 2295.4707 - mean_absolute_error: 38.6843 - val_loss: 1880.2473 - val_mean_absolute_error: 42.7467
# Epoch 35/100
# 7/7 [==============================] - 0s 9ms/step - loss: 1553.2471 - mean_absolute_error: 32.3950 - val_loss: 1063.7440 - val_mean_absolute_error: 31.7927
# Epoch 36/100
# 7/7 [==============================] - 0s 7ms/step - loss: 1208.7622 - mean_absolute_error: 29.3995 - val_loss: 587.7869 - val_mean_absolute_error: 23.1262
# Epoch 37/100
# 7/7 [==============================] - 0s 7ms/step - loss: 1034.0244 - mean_absolute_error: 27.2562 - val_loss: 370.5418 - val_mean_absolute_error: 17.8206
# Epoch 38/100
# 7/7 [==============================] - 0s 7ms/step - loss: 1004.9512 - mean_absolute_error: 26.7931 - val_loss: 256.9197 - val_mean_absolute_error: 14.3965
# Epoch 39/100
# 7/7 [==============================] - 0s 7ms/step - loss: 1014.7542 - mean_absolute_error: 26.8981 - val_loss: 213.0640 - val_mean_absolute_error: 12.8986
# Epoch 40/100
# 7/7 [==============================] - 0s 7ms/step - loss: 1015.2948 - mean_absolute_error: 26.9383 - val_loss: 212.3675 - val_mean_absolute_error: 12.8732
# Epoch 41/100
# 7/7 [==============================] - 0s 8ms/step - loss: 1014.4295 - mean_absolute_error: 26.9292 - val_loss: 221.0242 - val_mean_absolute_error: 13.1844
# Epoch 42/100
# 7/7 [==============================] - 0s 9ms/step - loss: 1012.4626 - mean_absolute_error: 26.9049 - val_loss: 237.0743 - val_mean_absolute_error: 13.7410
# Epoch 43/100
# 7/7 [==============================] - 0s 12ms/step - loss: 1010.6921 - mean_absolute_error: 26.8749 - val_loss: 253.9144 - val_mean_absolute_error: 14.2994
# Epoch 44/100
# 7/7 [==============================] - 0s 8ms/step - loss: 1010.2881 - mean_absolute_error: 26.8672 - val_loss: 261.3696 - val_mean_absolute_error: 14.5391
# Epoch 45/100
# 7/7 [==============================] - 0s 8ms/step - loss: 1011.5492 - mean_absolute_error: 26.8681 - val_loss: 275.5190 - val_mean_absolute_error: 14.9826
# Epoch 46/100
# 7/7 [==============================] - 0s 8ms/step - loss: 1010.3147 - mean_absolute_error: 26.8554 - val_loss: 262.5497 - val_mean_absolute_error: 14.5767
# Epoch 47/100
# 7/7 [==============================] - 0s 7ms/step - loss: 1010.4611 - mean_absolute_error: 26.8724 - val_loss: 252.9420 - val_mean_absolute_error: 14.2678
# Epoch 48/100
# 7/7 [==============================] - 0s 7ms/step - loss: 1010.6503 - mean_absolute_error: 26.8758 - val_loss: 254.5910 - val_mean_absolute_error: 14.3213
# Epoch 49/100
# 7/7 [==============================] - 0s 7ms/step - loss: 1010.9221 - mean_absolute_error: 26.8784 - val_loss: 249.5321 - val_mean_absolute_error: 14.1564
# Epoch 50/100
# 7/7 [==============================] - 0s 11ms/step - loss: 1010.8546 - mean_absolute_error: 26.8786 - val_loss: 249.8660 - val_mean_absolute_error: 14.1674
# Epoch 51/100
# 7/7 [==============================] - 0s 10ms/step - loss: 1010.9445 - mean_absolute_error: 26.8803 - val_loss: 254.7645 - val_mean_absolute_error: 14.3270
# Epoch 52/100
# 7/7 [==============================] - 0s 7ms/step - loss: 1008.9617 - mean_absolute_error: 26.8359 - val_loss: 277.9382 - val_mean_absolute_error: 15.0570
# Epoch 53/100
# 7/7 [==============================] - 0s 8ms/step - loss: 1012.2939 - mean_absolute_error: 26.9086 - val_loss: 317.4119 - val_mean_absolute_error: 16.2713
# Epoch 54/100
# 7/7 [==============================] - 0s 7ms/step - loss: 1001.3069 - mean_absolute_error: 26.7927 - val_loss: 344.6463 - val_mean_absolute_error: 17.1013
# Epoch 55/100
# 7/7 [==============================] - 0s 10ms/step - loss: 996.3276 - mean_absolute_error: 26.6936 - val_loss: 295.6235 - val_mean_absolute_error: 15.5986
# Epoch 56/100
# 7/7 [==============================] - 0s 7ms/step - loss: 980.0364 - mean_absolute_error: 26.4786 - val_loss: 361.6867 - val_mean_absolute_error: 17.6158
# Epoch 57/100
# 7/7 [==============================] - 0s 7ms/step - loss: 975.4736 - mean_absolute_error: 26.4115 - val_loss: 304.5731 - val_mean_absolute_error: 15.9095
# Epoch 58/100
# 7/7 [==============================] - 0s 7ms/step - loss: 962.5593 - mean_absolute_error: 26.2254 - val_loss: 366.2181 - val_mean_absolute_error: 17.7504
# Epoch 59/100
# 7/7 [==============================] - 0s 7ms/step - loss: 962.0195 - mean_absolute_error: 26.2658 - val_loss: 278.6489 - val_mean_absolute_error: 15.1163
# Epoch 60/100
# 7/7 [==============================] - 0s 10ms/step - loss: 949.1392 - mean_absolute_error: 26.0604 - val_loss: 308.2989 - val_mean_absolute_error: 16.0507
# Epoch 61/100
# 7/7 [==============================] - 0s 8ms/step - loss: 944.1636 - mean_absolute_error: 25.9636 - val_loss: 275.3907 - val_mean_absolute_error: 15.0267
# Epoch 62/100
# 7/7 [==============================] - 0s 12ms/step - loss: 932.8423 - mean_absolute_error: 25.8174 - val_loss: 254.4113 - val_mean_absolute_error: 14.3700
# Epoch 63/100
# 7/7 [==============================] - 0s 8ms/step - loss: 925.6234 - mean_absolute_error: 25.7067 - val_loss: 241.2065 - val_mean_absolute_error: 13.9435
# Epoch 64/100
# 7/7 [==============================] - 0s 11ms/step - loss: 930.0927 - mean_absolute_error: 25.7601 - val_loss: 235.3010 - val_mean_absolute_error: 13.7503
# Epoch 65/100
# 7/7 [==============================] - 0s 9ms/step - loss: 916.7573 - mean_absolute_error: 25.5882 - val_loss: 234.4604 - val_mean_absolute_error: 13.7304
# Epoch 66/100
# 7/7 [==============================] - 0s 8ms/step - loss: 902.8820 - mean_absolute_error: 25.3464 - val_loss: 275.1562 - val_mean_absolute_error: 15.0566
# Epoch 67/100
# 7/7 [==============================] - 0s 6ms/step - loss: 898.5782 - mean_absolute_error: 25.3292 - val_loss: 248.4326 - val_mean_absolute_error: 14.2015
# Epoch 68/100
# 7/7 [==============================] - 0s 7ms/step - loss: 905.4832 - mean_absolute_error: 25.3948 - val_loss: 319.5517 - val_mean_absolute_error: 16.4610
# Epoch 69/100
# 7/7 [==============================] - 0s 7ms/step - loss: 877.3427 - mean_absolute_error: 25.0462 - val_loss: 263.1995 - val_mean_absolute_error: 14.6875
# Epoch 70/100
# 7/7 [==============================] - 0s 7ms/step - loss: 838.1473 - mean_absolute_error: 24.4230 - val_loss: 307.9996 - val_mean_absolute_error: 16.1752
# Epoch 71/100
# 7/7 [==============================] - 0s 6ms/step - loss: 800.5623 - mean_absolute_error: 23.9009 - val_loss: 237.3812 - val_mean_absolute_error: 13.9087
# Epoch 72/100
# 7/7 [==============================] - 0s 7ms/step - loss: 756.5298 - mean_absolute_error: 23.2012 - val_loss: 295.1642 - val_mean_absolute_error: 15.8438
# Epoch 73/100
# 7/7 [==============================] - 0s 7ms/step - loss: 713.5903 - mean_absolute_error: 22.4167 - val_loss: 241.0816 - val_mean_absolute_error: 14.0795
# Epoch 74/100
# 7/7 [==============================] - 0s 8ms/step - loss: 666.1179 - mean_absolute_error: 21.6970 - val_loss: 169.3243 - val_mean_absolute_error: 11.4825
# Epoch 75/100
# 7/7 [==============================] - 0s 7ms/step - loss: 618.1078 - mean_absolute_error: 20.7853 - val_loss: 115.1207 - val_mean_absolute_error: 9.0027
# Epoch 76/100
# 7/7 [==============================] - 0s 6ms/step - loss: 601.0414 - mean_absolute_error: 20.4879 - val_loss: 294.1845 - val_mean_absolute_error: 15.9917
# Epoch 77/100
# 7/7 [==============================] - 0s 6ms/step - loss: 518.8008 - mean_absolute_error: 19.0883 - val_loss: 200.1621 - val_mean_absolute_error: 12.7694
# Epoch 78/100
# 7/7 [==============================] - 0s 7ms/step - loss: 455.6574 - mean_absolute_error: 17.7474 - val_loss: 211.4566 - val_mean_absolute_error: 13.2433
# Epoch 79/100
# 7/7 [==============================] - 0s 7ms/step - loss: 402.0696 - mean_absolute_error: 16.5678 - val_loss: 277.3192 - val_mean_absolute_error: 15.5865
# Epoch 80/100
# 7/7 [==============================] - 0s 8ms/step - loss: 388.6471 - mean_absolute_error: 16.1309 - val_loss: 88.0734 - val_mean_absolute_error: 7.8341
# Epoch 81/100
# 7/7 [==============================] - 0s 6ms/step - loss: 336.8428 - mean_absolute_error: 15.1432 - val_loss: 75.0919 - val_mean_absolute_error: 7.1198
# Epoch 82/100
# 7/7 [==============================] - 0s 7ms/step - loss: 277.2916 - mean_absolute_error: 13.4930 - val_loss: 62.4845 - val_mean_absolute_error: 6.3988
# Epoch 83/100
# 7/7 [==============================] - 0s 6ms/step - loss: 237.8804 - mean_absolute_error: 12.2323 - val_loss: 49.4779 - val_mean_absolute_error: 5.6631
# Epoch 84/100
# 7/7 [==============================] - 0s 6ms/step - loss: 184.0811 - mean_absolute_error: 10.4548 - val_loss: 41.5948 - val_mean_absolute_error: 5.3324
# Epoch 85/100
# 7/7 [==============================] - 0s 6ms/step - loss: 148.5488 - mean_absolute_error: 9.3210 - val_loss: 32.7201 - val_mean_absolute_error: 4.9889
# Epoch 86/100
# 7/7 [==============================] - 0s 7ms/step - loss: 122.1609 - mean_absolute_error: 8.3632 - val_loss: 39.5199 - val_mean_absolute_error: 5.2933
# Epoch 87/100
# 7/7 [==============================] - 0s 6ms/step - loss: 102.1265 - mean_absolute_error: 7.7027 - val_loss: 32.7692 - val_mean_absolute_error: 5.0069
# Epoch 88/100
# 7/7 [==============================] - 0s 6ms/step - loss: 78.5627 - mean_absolute_error: 6.3408 - val_loss: 30.2343 - val_mean_absolute_error: 4.8748
# Epoch 89/100
# 7/7 [==============================] - 0s 7ms/step - loss: 66.6093 - mean_absolute_error: 5.9366 - val_loss: 43.0156 - val_mean_absolute_error: 5.2552
# Epoch 90/100
# 7/7 [==============================] - 0s 7ms/step - loss: 60.8728 - mean_absolute_error: 6.0204 - val_loss: 35.2004 - val_mean_absolute_error: 4.8929
# Epoch 91/100
# 7/7 [==============================] - 0s 7ms/step - loss: 52.8670 - mean_absolute_error: 5.5848 - val_loss: 30.5918 - val_mean_absolute_error: 4.8536
# Epoch 92/100
# 7/7 [==============================] - 0s 7ms/step - loss: 53.5999 - mean_absolute_error: 5.6111 - val_loss: 65.0392 - val_mean_absolute_error: 6.4162
# Epoch 93/100
# 7/7 [==============================] - 0s 10ms/step - loss: 51.0297 - mean_absolute_error: 5.6607 - val_loss: 41.5803 - val_mean_absolute_error: 5.1075
# Epoch 94/100
# 7/7 [==============================] - 0s 6ms/step - loss: 40.0208 - mean_absolute_error: 4.8008 - val_loss: 40.4092 - val_mean_absolute_error: 5.0654
# Epoch 95/100
# 7/7 [==============================] - 0s 6ms/step - loss: 38.1172 - mean_absolute_error: 4.7302 - val_loss: 66.7813 - val_mean_absolute_error: 6.4991
# Epoch 96/100
# 7/7 [==============================] - 0s 7ms/step - loss: 45.6454 - mean_absolute_error: 5.4222 - val_loss: 36.7239 - val_mean_absolute_error: 4.9226
# Epoch 97/100
# 7/7 [==============================] - 0s 9ms/step - loss: 37.5736 - mean_absolute_error: 4.8883 - val_loss: 46.6446 - val_mean_absolute_error: 5.8387
# Epoch 98/100
# 7/7 [==============================] - 0s 6ms/step - loss: 49.0057 - mean_absolute_error: 5.6323 - val_loss: 31.2828 - val_mean_absolute_error: 4.8033
# Epoch 99/100
# 7/7 [==============================] - 0s 7ms/step - loss: 42.8963 - mean_absolute_error: 5.2618 - val_loss: 71.0949 - val_mean_absolute_error: 6.7441
# Epoch 100/100
# 7/7 [==============================] - 0s 6ms/step - loss: 37.6751 - mean_absolute_error: 4.8899 - val_loss: 69.0312 - val_mean_absolute_error: 6.6102

# %%
train_predictions = model.predict(X_train).flatten()

plt.plot(dates_train, train_predictions)
plt.plot(dates_train, y_train)
plt.legend(['Training Predictions', 'Training Observations'])
# Out:
# 7/7 [==============================] - 1s 2ms/step

# %%
val_predictions = model.predict(X_val).flatten()

plt.plot(dates_val, val_predictions)
plt.plot(dates_val, y_val)
plt.legend(['Validation Predictions', 'Validation Observations'])
# Out:
# 1/1 [==============================] - 0s 55ms/step

# %%
test_predictions = model.predict(X_test).flatten()

plt.plot(dates_test, test_predictions)
plt.plot(dates_test, y_test)
plt.legend(['Testing Predictions', 'Testing Observations'])
# Out:
# 1/1 [==============================] - 0s 16ms/step

# %%
plt.plot(dates_train, train_predictions)
plt.plot(dates_train, y_train)
plt.plot(dates_val, val_predictions)
plt.plot(dates_val, y_val)
plt.plot(dates_test, test_predictions)
plt.plot(dates_test, y_test)
plt.legend(['Training Predictions',
            'Training Observations',
            'Validation Predictions',
            'Validation Observations',
            'Testing Predictions',
            'Testing Observations'])

# %%
from copy import deepcopy

recursive_predictions = []
recursive_dates = np.concatenate([dates_val, dates_test])

for target_date in recursive_dates:
  last_window = deepcopy(X_train[-1])
  next_prediction = model.predict(np.array([last_window])).flatten()
  recursive_predictions.append(next_prediction)
  last_window[-1] = next_prediction
# Out:
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step

# %%
plt.plot(dates_train, train_predictions)
plt.plot(dates_train, y_train)
plt.plot(dates_val, val_predictions)
plt.plot(dates_val, y_val)
plt.plot(dates_test, test_predictions)
plt.plot(dates_test, y_test)
plt.plot(recursive_dates, recursive_predictions)
plt.legend(['Training Predictions',
            'Training Observations',
            'Validation Predictions',
            'Validation Observations',
            'Testing Predictions',
            'Testing Observations',
            'Recursive Predictions'])
